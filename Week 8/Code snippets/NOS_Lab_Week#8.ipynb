# %% [markdown]
# # Networks and Operating Systems
# ## CPU and Network Monitoring using Python
#
# ### 13 March 2025

# %%
import platform
import psutil

print("===== SYSTEM INFORMATION =====")
print(f"System: {platform.system()} {platform.release()}")
print(f"Processor: {platform.processor()}")
print(f"CPU Cores: {psutil.cpu_count(logical=False)}")
print(f"Logical Processors: {psutil.cpu_count(logical=True)}")
print(f"Total RAM: {psutil.virtual_memory().total / (1024**3):.2f} GB")

print("\n===== DISK INFORMATION =====")
for partition in psutil.disk_partitions():
    print(f"Device: {partition.device}, Mount: {partition.mountpoint}, Type: {partition.fstype}")
# Out:
# ===== SYSTEM INFORMATION =====
# System: Windows 11
# Processor: Intel64 Family 6 Model 186 Stepping 2, GenuineIntel
# CPU Cores: 12
# Logical Processors: 16
# Total RAM: 15.70 GB
#
# ===== DISK INFORMATION =====
# Device: C:\, Mount: C:\, Type: NTFS

# %%
import psutil

print("===== RUNNING PROCESSES =====")
for proc in psutil.process_iter(attrs=['pid', 'name', 'cpu_percent']):
    print(f"PID: {proc.info['pid']}, Name: {proc.info['name']}, CPU Usage: {proc.info['cpu_percent']}%")
# Out:
# ===== RUNNING PROCESSES =====
# PID: 0, Name: System Idle Process, CPU Usage: 0.0%
# PID: 4, Name: System, CPU Usage: 0.0%
# PID: 236, Name: , CPU Usage: 0.0%
# PID: 280, Name: Registry, CPU Usage: 0.0%
# PID: 848, Name: smss.exe, CPU Usage: 0.0%
# PID: 1072, Name: csrss.exe, CPU Usage: 0.0%
# PID: 1156, Name: wininit.exe, CPU Usage: 0.0%
# PID: 1164, Name: csrss.exe, CPU Usage: 0.0%
# PID: 1256, Name: winlogon.exe, CPU Usage: 0.0%
# PID: 1276, Name: services.exe, CPU Usage: 0.0%
# PID: 1312, Name: LsaIso.exe, CPU Usage: 0.0%
# PID: 1332, Name: lsass.exe, CPU Usage: 0.0%
# PID: 1356, Name: svchost.exe, CPU Usage: 0.0%
# PID: 1360, Name: svchost.exe, CPU Usage: 0.0%
# PID: 1396, Name: svchost.exe, CPU Usage: 0.0%
# PID: 1460, Name: svchost.exe, CPU Usage: 0.0%
# PID: 1480, Name: fontdrvhost.exe, CPU Usage: 0.0%
# PID: 1488, Name: fontdrvhost.exe, CPU Usage: 0.0%
# PID: 1496, Name: conhost.exe, CPU Usage: 0.0%
# PID: 1572, Name: WUDFHost.exe, CPU Usage: 0.0%
# PID: 1632, Name: svchost.exe, CPU Usage: 0.0%
# PID: 1640, Name: svchost.exe, CPU Usage: 0.0%
# PID: 1680, Name: svchost.exe, CPU Usage: 0.0%
# PID: 1684, Name: svchost.exe, CPU Usage: 0.0%
# PID: 1728, Name: WUDFHost.exe, CPU Usage: 0.0%
# PID: 1792, Name: svchost.exe, CPU Usage: 0.0%
# PID: 1824, Name: dwm.exe, CPU Usage: 0.0%
# PID: 1904, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2004, Name: StartMenuExperienceHost.exe, CPU Usage: 0.0%
# PID: 2168, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2236, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2264, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2272, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2284, Name: IntelCpHDCPSvc.exe, CPU Usage: 0.0%
# PID: 2336, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2368, Name: firefox.exe, CPU Usage: 0.0%
# PID: 2400, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2468, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2500, Name: Code.exe, CPU Usage: 0.0%
# PID: 2508, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2556, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2568, Name: conhost.exe, CPU Usage: 0.0%
# PID: 2608, Name: conhost.exe, CPU Usage: 0.0%
# PID: 2652, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2680, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2740, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2816, Name: firefox.exe, CPU Usage: 0.0%
# PID: 2900, Name: svchost.exe, CPU Usage: 0.0%
# PID: 2912, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3048, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3192, Name: Code.exe, CPU Usage: 0.0%
# PID: 3296, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3324, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3336, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3432, Name: DAX3API.exe, CPU Usage: 0.0%
# PID: 3444, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3580, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3648, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3668, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3696, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3708, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3716, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3884, Name: MemCompression, CPU Usage: 0.0%
# PID: 3940, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3980, Name: svchost.exe, CPU Usage: 0.0%
# PID: 3988, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4092, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4280, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4320, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4396, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4424, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4496, Name: spoolsv.exe, CPU Usage: 0.0%
# PID: 4520, Name: firefox.exe, CPU Usage: 0.0%
# PID: 4592, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4600, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4668, Name: IDBWM.exe, CPU Usage: 0.0%
# PID: 4732, Name: dasHost.exe, CPU Usage: 0.0%
# PID: 4768, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4784, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4820, Name: svchost.exe, CPU Usage: 0.0%
# PID: 4828, Name: WUDFHost.exe, CPU Usage: 0.0%
# PID: 4928, Name: NgcIso.exe, CPU Usage: 0.0%
# PID: 5016, Name: svchost.exe, CPU Usage: 0.0%
# PID: 5124, Name: OneApp.IGCC.WinService.exe, CPU Usage: 0.0%
# PID: 5132, Name: IntelAnalyticsService.exe, CPU Usage: 0.0%
# PID: 5156, Name: IntelAudioService.exe, CPU Usage: 0.0%
# PID: 5164, Name: SystemPlatformEngine.exe, CPU Usage: 0.0%
# PID: 5192, Name: BulletService.exe, CPU Usage: 0.0%
# PID: 5200, Name: spdsvc.exe, CPU Usage: 0.0%
# PID: 5208, Name: AircommandService.exe, CPU Usage: 0.0%
# PID: 5216, Name: ipfsvc.exe, CPU Usage: 0.0%
# PID: 5224, Name: jhi_service.exe, CPU Usage: 0.0%
# PID: 5232, Name: WMIRegistrationService.exe, CPU Usage: 0.0%
# PID: 5240, Name: SUService.exe, CPU Usage: 0.0%
# PID: 5248, Name: RtkAudUService64.exe, CPU Usage: 0.0%
# PID: 5256, Name: SamsungSARMode.exe, CPU Usage: 0.0%
# PID: 5276, Name: svchost.exe, CPU Usage: 0.0%
# PID: 5308, Name: GoodixWOTService_0.0.0.4.exe, CPU Usage: 0.0%
# PID: 5324, Name: svchost.exe, CPU Usage: 0.0%
# PID: 5332, Name: SecUPDUtilSvc.exe, CPU Usage: 0.0%
# PID: 5340, Name: svchost.exe, CPU Usage: 0.0%
# PID: 5348, Name: svchost.exe, CPU Usage: 0.0%
# PID: 5372, Name: MsMpEng.exe, CPU Usage: 0.0%
# PID: 5380, Name: MpDefenderCoreService.exe, CPU Usage: 0.0%
# PID: 5396, Name: ipf_uf.exe, CPU Usage: 0.0%
# PID: 5444, Name: Code.exe, CPU Usage: 0.0%
# PID: 5668, Name: backgroundTaskHost.exe, CPU Usage: 0.0%
# PID: 5692, Name: WUDFHost.exe, CPU Usage: 0.0%
# PID: 5816, Name: svchost.exe, CPU Usage: 0.0%
# PID: 5936, Name: SecondScreen.exe, CPU Usage: 0.0%
# PID: 6072, Name: svchost.exe, CPU Usage: 0.0%
# PID: 6176, Name: Code.exe, CPU Usage: 0.0%
# PID: 6340, Name: IntelConnectivityNetworkService.exe, CPU Usage: 0.0%
# PID: 6400, Name: firefox.exe, CPU Usage: 0.0%
# PID: 6408, Name: firefox.exe, CPU Usage: 0.0%
# PID: 6580, Name: RuntimeBroker.exe, CPU Usage: 0.0%
# PID: 6668, Name: svchost.exe, CPU Usage: 0.0%
# PID: 6676, Name: ai.exe, CPU Usage: 0.0%
# PID: 6692, Name: svchost.exe, CPU Usage: 0.0%
# PID: 7064, Name: svchost.exe, CPU Usage: 0.0%
# PID: 7068, Name: IDBWMService.exe, CPU Usage: 0.0%
# PID: 7156, Name: WindowsMCFCore.exe, CPU Usage: 0.0%
# PID: 7172, Name: SecondScreenDesktop.exe, CPU Usage: 0.0%
# PID: 7212, Name: pet.exe, CPU Usage: 0.0%
# PID: 7244, Name: svchost.exe, CPU Usage: 0.0%
# PID: 7304, Name: IntelConnectService.exe, CPU Usage: 0.0%
# PID: 7356, Name: svchost.exe, CPU Usage: 0.0%
# PID: 7732, Name: conhost.exe, CPU Usage: 0.0%
# PID: 7740, Name: RtkAudUService64.exe, CPU Usage: 0.0%
# PID: 7792, Name: smartscreen.exe, CPU Usage: 0.0%
# PID: 7856, Name: svchost.exe, CPU Usage: 0.0%
# PID: 7888, Name: UserOOBEBroker.exe, CPU Usage: 0.0%
# PID: 7892, Name: backgroundTaskHost.exe, CPU Usage: 0.0%
# PID: 7968, Name: svchost.exe, CPU Usage: 0.0%
# PID: 8060, Name: SecurityHealthService.exe, CPU Usage: 0.0%
# PID: 8084, Name: Discord.exe, CPU Usage: 0.0%
# PID: 8136, Name: SamsungSystemSupportService.exe, CPU Usage: 0.0%
# PID: 8272, Name: svchost.exe, CPU Usage: 0.0%
# PID: 8404, Name: SUUserModeWorker.exe, CPU Usage: 0.0%
# PID: 8520, Name: conhost.exe, CPU Usage: 0.0%
# PID: 8616, Name: ipf_helper.exe, CPU Usage: 0.0%
# PID: 8632, Name: svchost.exe, CPU Usage: 0.0%
# PID: 8652, Name: SamsungAnalyticsService.exe, CPU Usage: 0.0%
# PID: 8688, Name: firefox.exe, CPU Usage: 0.0%
# PID: 8700, Name: sihost.exe, CPU Usage: 0.0%
# PID: 8728, Name: svchost.exe, CPU Usage: 0.0%
# PID: 8744, Name: svchost.exe, CPU Usage: 0.0%
# PID: 8756, Name: svchost.exe, CPU Usage: 0.0%
# PID: 8840, Name: svchost.exe, CPU Usage: 0.0%
# PID: 8932, Name: svchost.exe, CPU Usage: 0.0%
# PID: 8944, Name: SearchIndexer.exe, CPU Usage: 0.0%
# PID: 9000, Name: SamsungMultiControlService.exe, CPU Usage: 0.0%
# PID: 9008, Name: taskhostw.exe, CPU Usage: 0.0%
# PID: 9016, Name: ColorEngine.exe, CPU Usage: 0.0%
# PID: 9024, Name: LoopbackExemptionManager.exe, CPU Usage: 0.0%
# PID: 9084, Name: DisplaySupporter.exe, CPU Usage: 0.0%
# PID: 9168, Name: svchost.exe, CPU Usage: 0.0%
# PID: 9324, Name: Discord.exe, CPU Usage: 0.0%
# PID: 9360, Name: NisSrv.exe, CPU Usage: 0.0%
# PID: 9436, Name: svchost.exe, CPU Usage: 0.0%
# PID: 9476, Name: DAX3API.exe, CPU Usage: 0.0%
# PID: 9508, Name: SUEngine.exe, CPU Usage: 0.0%
# PID: 9720, Name: backgroundTaskHost.exe, CPU Usage: 0.0%
# PID: 9904, Name: GitHubDesktop.exe, CPU Usage: 0.0%
# PID: 9952, Name: ctfmon.exe, CPU Usage: 0.0%
# PID: 9956, Name: svchost.exe, CPU Usage: 0.0%
# PID: 10004, Name: svchost.exe, CPU Usage: 0.0%
# PID: 10216, Name: dllhost.exe, CPU Usage: 0.0%
# PID: 10236, Name: powershell.exe, CPU Usage: 0.0%
# PID: 10344, Name: svchost.exe, CPU Usage: 0.0%
# PID: 10416, Name: svchost.exe, CPU Usage: 0.0%
# PID: 10460, Name: WmiPrvSE.exe, CPU Usage: 0.0%
# PID: 10536, Name: svchost.exe, CPU Usage: 0.0%
# PID: 10540, Name: svchost.exe, CPU Usage: 0.0%
# PID: 10616, Name: dllhost.exe, CPU Usage: 0.0%
# PID: 10676, Name: conhost.exe, CPU Usage: 0.0%
# PID: 10736, Name: IntelConnect.exe, CPU Usage: 0.0%
# PID: 10880, Name: AircommandEngine.exe, CPU Usage: 0.0%
# PID: 10920, Name: GitHubDesktop.exe, CPU Usage: 0.0%
# PID: 10928, Name: svchost.exe, CPU Usage: 0.0%
# PID: 11084, Name: AggregatorHost.exe, CPU Usage: 0.0%
# PID: 11104, Name: firefox.exe, CPU Usage: 0.0%
# PID: 11212, Name: Code.exe, CPU Usage: 0.0%
# PID: 11452, Name: python.exe, CPU Usage: 0.0%
# PID: 11504, Name: TabTip.exe, CPU Usage: 0.0%
# PID: 11564, Name: POWERPNT.EXE, CPU Usage: 0.0%
# PID: 11600, Name: conhost.exe, CPU Usage: 0.0%
# PID: 11612, Name: svchost.exe, CPU Usage: 0.0%
# PID: 11644, Name: OfficeClickToRun.exe, CPU Usage: 0.0%
# PID: 11660, Name: TrustedInstaller.exe, CPU Usage: 0.0%
# PID: 11708, Name: svchost.exe, CPU Usage: 0.0%
# PID: 11712, Name: SamsungSystemSupportEngine.exe, CPU Usage: 0.0%
# PID: 11840, Name: dllhost.exe, CPU Usage: 0.0%
# PID: 12004, Name: GitHubDesktop.exe, CPU Usage: 0.0%
# PID: 12152, Name: svchost.exe, CPU Usage: 0.0%
# PID: 12292, Name: svchost.exe, CPU Usage: 0.0%
# PID: 12348, Name: WidgetService.exe, CPU Usage: 0.0%
# PID: 12408, Name: RuntimeBroker.exe, CPU Usage: 0.0%
# PID: 12528, Name: OfficeC2RClient.exe, CPU Usage: 0.0%
# PID: 12576, Name: Code.exe, CPU Usage: 0.0%
# PID: 12840, Name: svchost.exe, CPU Usage: 0.0%
# PID: 13028, Name: conhost.exe, CPU Usage: 0.0%
# PID: 13032, Name: AppVShNotify.exe, CPU Usage: 0.0%
# PID: 13144, Name: svchost.exe, CPU Usage: 0.0%
# PID: 13180, Name: python.exe, CPU Usage: 0.0%
# PID: 13376, Name: Code.exe, CPU Usage: 0.0%
# PID: 13652, Name: Code.exe, CPU Usage: 0.0%
# PID: 13796, Name: RuntimeBroker.exe, CPU Usage: 0.0%
# PID: 13804, Name: firefox.exe, CPU Usage: 0.0%
# PID: 14152, Name: svchost.exe, CPU Usage: 0.0%
# PID: 14496, Name: CDASrv.exe, CPU Usage: 0.0%
# PID: 14736, Name: svchost.exe, CPU Usage: 0.0%
# PID: 14752, Name: Code.exe, CPU Usage: 0.0%
# PID: 14832, Name: svchost.exe, CPU Usage: 0.0%
# PID: 14972, Name: Code.exe, CPU Usage: 0.0%
# PID: 15032, Name: Discord.exe, CPU Usage: 0.0%
# PID: 15156, Name: svchost.exe, CPU Usage: 0.0%
# PID: 15236, Name: svchost.exe, CPU Usage: 0.0%
# PID: 15276, Name: svchost.exe, CPU Usage: 0.0%
# PID: 15496, Name: Code.exe, CPU Usage: 0.0%
# PID: 15684, Name: wlanext.exe, CPU Usage: 0.0%
# PID: 15736, Name: ApplicationFrameHost.exe, CPU Usage: 0.0%
# PID: 16108, Name: firefox.exe, CPU Usage: 0.0%
# PID: 16452, Name: SearchHost.exe, CPU Usage: 0.0%
# PID: 16488, Name: TextInputHost.exe, CPU Usage: 0.0%
# PID: 16528, Name: firefox.exe, CPU Usage: 0.0%
# PID: 16628, Name: firefox.exe, CPU Usage: 0.0%
# PID: 16984, Name: CodeSetup-stable-ddc367ed5c8936efe395cffeec279b04ffd7db78.tmp, CPU Usage: 0.0%
# PID: 17116, Name: Code.exe, CPU Usage: 0.0%
# PID: 17164, Name: Code.exe, CPU Usage: 0.0%
# PID: 17176, Name: firefox.exe, CPU Usage: 0.0%
# PID: 17236, Name: firefox.exe, CPU Usage: 0.0%
# PID: 17380, Name: CodeSetup-stable-ddc367ed5c8936efe395cffeec279b04ffd7db78.exe, CPU Usage: 0.0%
# PID: 17492, Name: powershell.exe, CPU Usage: 0.0%
# PID: 17560, Name: firefox.exe, CPU Usage: 0.0%
# PID: 17656, Name: svchost.exe, CPU Usage: 0.0%
# PID: 17688, Name: LockApp.exe, CPU Usage: 0.0%
# PID: 18032, Name: Discord.exe, CPU Usage: 0.0%
# PID: 18080, Name: Code.exe, CPU Usage: 0.0%
# PID: 18536, Name: Code.exe, CPU Usage: 0.0%
# PID: 18580, Name: Photos.exe, CPU Usage: 0.0%
# PID: 18700, Name: RuntimeBroker.exe, CPU Usage: 0.0%
# PID: 18924, Name: Discord.exe, CPU Usage: 0.0%
# PID: 18956, Name: SamsungSARWin.exe, CPU Usage: 0.0%
# PID: 18992, Name: Code.exe, CPU Usage: 0.0%
# PID: 19020, Name: backgroundTaskHost.exe, CPU Usage: 0.0%
# PID: 19168, Name: Discord.exe, CPU Usage: 0.0%
# PID: 19204, Name: conhost.exe, CPU Usage: 0.0%
# PID: 19320, Name: firefox.exe, CPU Usage: 0.0%
# PID: 19396, Name: GitHubDesktop.exe, CPU Usage: 0.0%
# PID: 19452, Name: ShellHost.exe, CPU Usage: 0.0%
# PID: 19840, Name: SearchFilterHost.exe, CPU Usage: 0.0%
# PID: 19908, Name: Widgets.exe, CPU Usage: 0.0%
# PID: 19960, Name: powershell.exe, CPU Usage: 0.0%
# PID: 20064, Name: powershell.exe, CPU Usage: 0.0%
# PID: 20404, Name: python.exe, CPU Usage: 0.0%
# PID: 20432, Name: PhoneExperienceHost.exe, CPU Usage: 0.0%
# PID: 20568, Name: RuntimeBroker.exe, CPU Usage: 0.0%
# PID: 21092, Name: python.exe, CPU Usage: 0.0%
# PID: 21116, Name: TiWorker.exe, CPU Usage: 0.0%
# PID: 21748, Name: ShellExperienceHost.exe, CPU Usage: 0.0%
# PID: 21936, Name: firefox.exe, CPU Usage: 0.0%
# PID: 21976, Name: Discord.exe, CPU Usage: 0.0%
# PID: 22048, Name: svchost.exe, CPU Usage: 0.0%
# PID: 22200, Name: WmiPrvSE.exe, CPU Usage: 0.0%
# PID: 22472, Name: Code.exe, CPU Usage: 0.0%
# PID: 22688, Name: conhost.exe, CPU Usage: 0.0%
# PID: 22700, Name: svchost.exe, CPU Usage: 0.0%
# PID: 22848, Name: conhost.exe, CPU Usage: 0.0%
# PID: 22940, Name: svchost.exe, CPU Usage: 0.0%
# PID: 23016, Name: backgroundTaskHost.exe, CPU Usage: 0.0%
# PID: 23208, Name: conhost.exe, CPU Usage: 0.0%
# PID: 23280, Name: pet.exe, CPU Usage: 0.0%
# PID: 23340, Name: Code.exe, CPU Usage: 0.0%
# PID: 23392, Name: firefox.exe, CPU Usage: 0.0%
# PID: 23584, Name: backgroundTaskHost.exe, CPU Usage: 0.0%
# PID: 23616, Name: gamingservices.exe, CPU Usage: 0.0%
# PID: 23696, Name: SearchProtocolHost.exe, CPU Usage: 0.0%
# PID: 24008, Name: gamingservicesnet.exe, CPU Usage: 0.0%
# PID: 24556, Name: powershell.exe, CPU Usage: 0.0%
# PID: 25080, Name: MoNotificationUx.exe, CPU Usage: 0.0%
# PID: 25664, Name: conhost.exe, CPU Usage: 0.0%
# PID: 25724, Name: backgroundTaskHost.exe, CPU Usage: 0.0%
# PID: 25812, Name: audiodg.exe, CPU Usage: 0.0%
# PID: 25908, Name: SamsungWiFi_UHB_Setting_Service.exe, CPU Usage: 0.0%
# PID: 26060, Name: Intel_PIE_Service.exe, CPU Usage: 0.0%
# PID: 26148, Name: explorer.exe, CPU Usage: 0.0%
# PID: 26168, Name: conhost.exe, CPU Usage: 0.0%
# PID: 26552, Name: taskhostw.exe, CPU Usage: 0.0%
# PID: 26840, Name: SnippingTool.exe, CPU Usage: 0.0%
# PID: 26868, Name: svchost.exe, CPU Usage: 0.0%
# PID: 26908, Name: ScreenMode.exe, CPU Usage: 0.0%
# PID: 27500, Name: powershell.exe, CPU Usage: 0.0%
# PID: 28236, Name: Code.exe, CPU Usage: 0.0%
# PID: 28428, Name: Microsoft.SharePoint.exe, CPU Usage: 0.0%

# %%
vm = psutil.virtual_memory()
swap = psutil.swap_memory()

print("===== MEMORY USAGE =====")
print(f"Total RAM: {vm.total / (1024**3):.2f} GB")
print(f"Available RAM: {vm.available / (1024**3):.2f} GB")
print(f"Used RAM: {vm.used / (1024**3):.2f} GB")
print(f"Memory Usage: {vm.percent}%")

print("\n===== VIRTUAL MEMORY =====")
print(f"Total Swap: {swap.total / (1024**3):.2f} GB")
print(f"Used Swap: {swap.used / (1024**3):.2f} GB")
print(f"Swap Usage: {swap.percent}%")
# Out:
# ===== MEMORY USAGE =====
# Total RAM: 15.70 GB
# Available RAM: 3.56 GB
# Used RAM: 12.14 GB
# Memory Usage: 77.3%
#
# ===== VIRTUAL MEMORY =====
# Total Swap: 3.02 GB
# Used Swap: 0.19 GB
# Swap Usage: 6.4%

# %%
import time

try:
    print("Running... Press Ctrl+C to interrupt")
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    print("\nInterrupt received! Exiting gracefully.")
# Out:
# Running... Press Ctrl+C to interrupt
#
# Interrupt received! Exiting gracefully.

# %%
import psutil

disk_io = psutil.disk_io_counters()
print("===== DISK I/O STATISTICS =====")
print(f"Read Count: {disk_io.read_count}")
print(f"Write Count: {disk_io.write_count}")
print(f"Read Bytes: {disk_io.read_bytes / (1024**2):.2f} MB")
print(f"Write Bytes: {disk_io.write_bytes / (1024**2):.2f} MB")
# Out:
# ===== DISK I/O STATISTICS =====
# Read Count: 4342783
# Write Count: 7441549
# Read Bytes: 132590.41 MB
# Write Bytes: 132370.32 MB

# %%
import psutil

print("===== ACTIVE NETWORK CONNECTIONS =====")
for conn in psutil.net_connections(kind="inet"):
    laddr = f"{conn.laddr.ip}:{conn.laddr.port}" if conn.laddr else "N/A"
    raddr = f"{conn.raddr.ip}:{conn.raddr.port}" if conn.raddr else "N/A"
    print(f"Type: {conn.type}, Status: {conn.status}, Local Addr: {laddr}, Remote Addr: {raddr}")
# Out:
# ===== ACTIVE NETWORK CONNECTIONS =====
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:9003, Remote Addr: 127.0.0.1:57760
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:49668, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:54249, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57744, Remote Addr: 127.0.0.1:57745
# Type: 1, Status: LISTEN, Local Addr: 127.0.0.1:9003, Remote Addr: N/A
# Type: 1, Status: TIME_WAIT, Local Addr: 127.0.0.1:57755, Remote Addr: 127.0.0.1:9002
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:64977, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: :::58861, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: :::49665, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57751, Remote Addr: 127.0.0.1:57750
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49681, Remote Addr: 127.0.0.1:49682
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57728, Remote Addr: 127.0.0.1:9002
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:58861, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:3702, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: :::445, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 127.0.0.1:6463, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57743, Remote Addr: 127.0.0.1:57742
# Type: 2, Status: NONE, Local Addr: ::1:1900, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49679, Remote Addr: 127.0.0.1:49678
# Type: 1, Status: LISTEN, Local Addr: :::5357, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: :::7260, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:5040, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:7260, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: ::1:42050, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:57334, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57718, Remote Addr: 127.0.0.1:57719
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:9002, Remote Addr: 127.0.0.1:57758
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:5357, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:7680, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49726, Remote Addr: 127.0.0.1:49725
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57714, Remote Addr: 127.0.0.1:57715
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57720, Remote Addr: 127.0.0.1:57721
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:9002, Remote Addr: 127.0.0.1:57728
# Type: 1, Status: TIME_WAIT, Local Addr: 2a02:6b67:eef0:bf00:65ef:b451:aea7:d3be:57658, Remote Addr: 2606:4700:4400::6812:202f:443
# Type: 2, Status: NONE, Local Addr: fe80::cbf:5465:8a1b:d789:65284, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: :::57334, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 127.0.0.1:60681, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49678, Remote Addr: 127.0.0.1:49679
# Type: 1, Status: TIME_WAIT, Local Addr: 192.168.1.217:57679, Remote Addr: 40.70.77.177:443
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57758, Remote Addr: 127.0.0.1:9002
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57740, Remote Addr: 127.0.0.1:57741
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57722, Remote Addr: 127.0.0.1:57723
# Type: 2, Status: NONE, Local Addr: 192.168.1.217:137, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 127.0.0.1:49664, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:49667, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 2a02:6b67:eef0:bf00:65ef:b451:aea7:d3be:49415, Remote Addr: 2603:1020:705:8::401:443
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57731, Remote Addr: 127.0.0.1:57732
# Type: 2, Status: NONE, Local Addr: ::1:65285, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 127.0.0.1:1900, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 2a02:6b67:eef0:bf00:65ef:b451:aea7:d3be:57537, Remote Addr: 2600:1901:1:a8:::443
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:5355, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57747, Remote Addr: 127.0.0.1:57746
# Type: 2, Status: NONE, Local Addr: :::3702, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 192.168.1.217:57610, Remote Addr: 140.82.113.26:443
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49682, Remote Addr: 127.0.0.1:49681
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57736, Remote Addr: 127.0.0.1:57735
# Type: 1, Status: LISTEN, Local Addr: :::49667, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 127.0.0.1:12753, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57757, Remote Addr: 127.0.0.1:9004
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57723, Remote Addr: 127.0.0.1:57722
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57725, Remote Addr: 127.0.0.1:57724
# Type: 1, Status: ESTABLISHED, Local Addr: 2a02:6b67:eef0:bf00:65ef:b451:aea7:d3be:57767, Remote Addr: 2a02:26f0:fd00:3::213:75a3:443
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49727, Remote Addr: 127.0.0.1:49728
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57752, Remote Addr: 127.0.0.1:57753
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57762, Remote Addr: 127.0.0.1:57761
# Type: 1, Status: LISTEN, Local Addr: :::135, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: :::50816, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 192.168.1.217:57533, Remote Addr: 34.107.243.93:443
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:55315, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 2a02:6b67:eef0:bf00:65ef:b451:aea7:d3be:57769, Remote Addr: 2620:1ec:bdf::64:443
# Type: 2, Status: NONE, Local Addr: :::123, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57741, Remote Addr: 127.0.0.1:57740
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57742, Remote Addr: 127.0.0.1:57743
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57729, Remote Addr: 127.0.0.1:57730
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57760, Remote Addr: 127.0.0.1:9003
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57732, Remote Addr: 127.0.0.1:57731
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:5050, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57749, Remote Addr: 127.0.0.1:57748
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:45823, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57712, Remote Addr: 127.0.0.1:57713
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:9001, Remote Addr: 127.0.0.1:57759
# Type: 1, Status: LISTEN, Local Addr: :::49664, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57761, Remote Addr: 127.0.0.1:57762
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57717, Remote Addr: 127.0.0.1:57716
# Type: 2, Status: NONE, Local Addr: 192.168.1.217:1900, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 127.0.0.1:50542, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57739, Remote Addr: 127.0.0.1:57738
# Type: 1, Status: LISTEN, Local Addr: 127.0.0.1:57737, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: :::60480, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57753, Remote Addr: 127.0.0.1:57752
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57721, Remote Addr: 127.0.0.1:57720
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:445, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 127.0.0.1:9004, Remote Addr: N/A
# Type: 1, Status: TIME_WAIT, Local Addr: 2a02:6b67:eef0:bf00:65ef:b451:aea7:d3be:57772, Remote Addr: 2a00:1450:4009:81d::200a:443
# Type: 2, Status: NONE, Local Addr: :::54249, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57748, Remote Addr: 127.0.0.1:57749
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57733, Remote Addr: 127.0.0.1:57734
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49725, Remote Addr: 127.0.0.1:49726
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:50816, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57730, Remote Addr: 127.0.0.1:57729
# Type: 2, Status: NONE, Local Addr: fe80::cbf:5465:8a1b:d789:1900, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:123, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: :::5355, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57724, Remote Addr: 127.0.0.1:57725
# Type: 1, Status: LISTEN, Local Addr: ::1:49669, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:54929, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: :::54929, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 127.0.0.1:9002, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: :::7680, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 192.168.1.217:57513, Remote Addr: 162.159.135.234:443
# Type: 1, Status: LISTEN, Local Addr: 127.0.0.1:9000, Remote Addr: N/A
# Type: 1, Status: TIME_WAIT, Local Addr: 192.168.1.217:57674, Remote Addr: 34.120.208.123:443
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57716, Remote Addr: 127.0.0.1:57717
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57735, Remote Addr: 127.0.0.1:57736
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:49664, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57719, Remote Addr: 127.0.0.1:57718
# Type: 1, Status: ESTABLISHED, Local Addr: 192.168.1.217:57700, Remote Addr: 20.189.173.4:443
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:60479, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57727, Remote Addr: 127.0.0.1:57726
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57713, Remote Addr: 127.0.0.1:57712
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57746, Remote Addr: 127.0.0.1:57747
# Type: 1, Status: LISTEN, Local Addr: 192.168.1.217:139, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:5353, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57745, Remote Addr: 127.0.0.1:57744
# Type: 1, Status: ESTABLISHED, Local Addr: 192.168.1.217:57692, Remote Addr: 140.82.112.25:443
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49677, Remote Addr: 127.0.0.1:49676
# Type: 1, Status: TIME_WAIT, Local Addr: 192.168.1.217:57698, Remote Addr: 52.168.117.170:443
# Type: 1, Status: LISTEN, Local Addr: :::49666, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57738, Remote Addr: 127.0.0.1:57739
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57734, Remote Addr: 127.0.0.1:57733
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57726, Remote Addr: 127.0.0.1:57727
# Type: 1, Status: LISTEN, Local Addr: :::49680, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: :::5353, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49728, Remote Addr: 127.0.0.1:49727
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57759, Remote Addr: 127.0.0.1:9001
# Type: 2, Status: NONE, Local Addr: 127.0.0.1:65287, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 192.168.1.217:138, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 192.168.1.217:65286, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57715, Remote Addr: 127.0.0.1:57714
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:135, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:9004, Remote Addr: 127.0.0.1:57757
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:49680, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: :::49668, Remote Addr: N/A
# Type: 2, Status: NONE, Local Addr: 0.0.0.0:61604, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: 127.0.0.1:9001, Remote Addr: N/A
# Type: 1, Status: LISTEN, Local Addr: :::45823, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:49676, Remote Addr: 127.0.0.1:49677
# Type: 1, Status: ESTABLISHED, Local Addr: 127.0.0.1:57750, Remote Addr: 127.0.0.1:57751
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:49665, Remote Addr: N/A
# Type: 1, Status: ESTABLISHED, Local Addr: 2a02:6b67:eef0:bf00:65ef:b451:aea7:d3be:57763, Remote Addr: 2606:4700::6811:f9cb:443
# Type: 1, Status: LISTEN, Local Addr: 0.0.0.0:49666, Remote Addr: N/A

# %%
import psutil
import time

print("===== CPU OVERLOAD MONITOR =====")
while True:
    cpu_usage = psutil.cpu_percent(interval=1)
    print(f"Current CPU Usage: {cpu_usage}%")
    
    if cpu_usage > 80:
        print("⚠️ Warning: High CPU usage detected! ⚠️")
    
    time.sleep(2)

#i interrupted thats the reason for the error
# Out:
# ===== CPU OVERLOAD MONITOR =====
# Current CPU Usage: 6.6%
# Current CPU Usage: 3.2%
# Current CPU Usage: 3.1%
# Current CPU Usage: 3.6%
# Current CPU Usage: 10.4%
# Current CPU Usage: 6.2%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 12
#       9 if cpu_usage > 80:
#      10     print("⚠️ Warning: High CPU usage detected! ⚠️")
# ---> 12 time.sleep(2)
#
# KeyboardInterrupt:

# %%
import psutil
import time

print("===== CPU USAGE MONITOR =====")
for _ in range(5):  # Check for 5 cycles
    # Get top 5 CPU-consuming processes
    processes = sorted(psutil.process_iter(attrs=['pid', 'name', 'cpu_percent']), key=lambda p: p.info['cpu_percent'], reverse=True)[:5]
    
    print("\nTop CPU-consuming processes:")
    for proc in processes:
        print(f"PID: {proc.info['pid']}, Name: {proc.info['name']}, CPU Usage: {proc.info['cpu_percent']}%")
    
    time.sleep(3)  # Wait before checking again
# Out:
# ===== CPU USAGE MONITOR =====
#
# Top CPU-consuming processes:
# PID: 0, Name: System Idle Process, CPU Usage: 1520.2%
# PID: 15496, Name: Code.exe, CPU Usage: 15.6%
# PID: 14972, Name: Code.exe, CPU Usage: 10.3%
# PID: 1824, Name: dwm.exe, CPU Usage: 10.1%
# PID: 4, Name: System, CPU Usage: 7.0%
#
# Top CPU-consuming processes:
# PID: 0, Name: System Idle Process, CPU Usage: 1518.8%
# PID: 14972, Name: Code.exe, CPU Usage: 15.7%
# PID: 15496, Name: Code.exe, CPU Usage: 14.9%
# PID: 13180, Name: python.exe, CPU Usage: 13.9%
# PID: 1824, Name: dwm.exe, CPU Usage: 7.2%
#
# Top CPU-consuming processes:
# PID: 0, Name: System Idle Process, CPU Usage: 1522.1%
# PID: 14972, Name: Code.exe, CPU Usage: 17.1%
# PID: 13180, Name: python.exe, CPU Usage: 14.0%
# PID: 15496, Name: Code.exe, CPU Usage: 13.5%
# PID: 1824, Name: dwm.exe, CPU Usage: 6.2%
#
# Top CPU-consuming processes:
# PID: 0, Name: System Idle Process, CPU Usage: 1532.3%
# PID: 14972, Name: Code.exe, CPU Usage: 14.4%
# PID: 13180, Name: python.exe, CPU Usage: 13.4%
# PID: 15496, Name: Code.exe, CPU Usage: 10.8%
# PID: 4, Name: System, CPU Usage: 5.0%
#
# Top CPU-consuming processes:
# PID: 0, Name: System Idle Process, CPU Usage: 1502.0%
# PID: 15496, Name: Code.exe, CPU Usage: 21.2%
# PID: 14972, Name: Code.exe, CPU Usage: 19.0%
# PID: 13180, Name: python.exe, CPU Usage: 13.1%
# PID: 4, Name: System, CPU Usage: 12.6%

# %%
print("===== MEMORY USAGE MONITOR =====")
processes = sorted(psutil.process_iter(attrs=['pid', 'name', 'memory_info']), key=lambda p: p.info['memory_info'].rss, reverse=True)[:5]

for proc in processes:
    mem_usage = proc.info['memory_info'].rss / (1024**2)  # Convert bytes to MB
    print(f"PID: {proc.info['pid']}, Name: {proc.info['name']}, Memory Usage: {mem_usage:.2f} MB")
# Out:
# ===== MEMORY USAGE MONITOR =====
# PID: 3884, Name: MemCompression, Memory Usage: 1146.12 MB
# PID: 6408, Name: firefox.exe, Memory Usage: 491.18 MB
# PID: 2368, Name: firefox.exe, Memory Usage: 437.08 MB
# PID: 15496, Name: Code.exe, Memory Usage: 392.03 MB
# PID: 26148, Name: explorer.exe, Memory Usage: 391.59 MB

# %% [markdown]
# ## Network Monitor

# %%
import psutil

print("===== NETWORK USAGE MONITOR =====")
net_io_before = psutil.net_io_counters()

# Wait for 3 seconds to measure network activity
import time
time.sleep(3)

net_io_after = psutil.net_io_counters()
bytes_sent = (net_io_after.bytes_sent - net_io_before.bytes_sent) / (1024**2)  # Convert to MB
bytes_recv = (net_io_after.bytes_recv - net_io_before.bytes_recv) / (1024**2)

print(f"Data Sent: {bytes_sent:.2f} MB")
print(f"Data Received: {bytes_recv:.2f} MB")
# Out:
# ===== NETWORK USAGE MONITOR =====
# Data Sent: 0.01 MB
# Data Received: 0.01 MB

# %% [markdown]
# ## CPU and Network

# %%
import psutil
import time

def monitor_system():
    print("\n===== SYSTEM MONITOR =====")
    
    # CPU Usage
    print(f"CPU Usage: {psutil.cpu_percent()}%")
    
    # Memory Usage
    mem = psutil.virtual_memory()
    print(f"Memory Used: {mem.used / (1024**3):.2f} GB / {mem.total / (1024**3):.2f} GB ({mem.percent}%)")

    # Top 3 Processes by CPU
    print("\nTop CPU-consuming processes:")
    for proc in sorted(psutil.process_iter(attrs=['pid', 'name', 'cpu_percent']), key=lambda p: p.info['cpu_percent'], reverse=True)[:3]:
        print(f"PID: {proc.info['pid']}, Name: {proc.info['name']}, CPU: {proc.info['cpu_percent']}%")

    # Network Usage
    net_io = psutil.net_io_counters()
    print(f"\nNetwork - Sent: {net_io.bytes_sent / (1024**2):.2f} MB, Received: {net_io.bytes_recv / (1024**2):.2f} MB")

print("Running Task Manager... Press Ctrl+C to stop.")
try:
    while True:
        monitor_system()
        time.sleep(5)
except KeyboardInterrupt:
    print("\nTask Manager Stopped.")
# Out:
# Running Task Manager... Press Ctrl+C to stop.
#
# ===== SYSTEM MONITOR =====
# CPU Usage: 5.5%
# Memory Used: 11.98 GB / 15.70 GB (76.3%)
#
# Top CPU-consuming processes:
# PID: 0, Name: System Idle Process, CPU: 1516.4%
# PID: 15496, Name: Code.exe, CPU: 20.2%
# PID: 14972, Name: Code.exe, CPU: 12.2%
#
# Network - Sent: 4.20 MB, Received: 27.07 MB
#
# ===== SYSTEM MONITOR =====
# CPU Usage: 6.5%
# Memory Used: 11.97 GB / 15.70 GB (76.2%)
#
# Top CPU-consuming processes:
# PID: 0, Name: System Idle Process, CPU: 1501.5%
# PID: 15496, Name: Code.exe, CPU: 25.4%
# PID: 14972, Name: Code.exe, CPU: 19.7%
#
# Network - Sent: 4.21 MB, Received: 27.08 MB
#
# ===== SYSTEM MONITOR =====
# CPU Usage: 7.2%
# Memory Used: 11.96 GB / 15.70 GB (76.2%)
#
# Top CPU-consuming processes:
# PID: 0, Name: System Idle Process, CPU: 1494.0%
# PID: 4820, Name: svchost.exe, CPU: 38.6%
# PID: 14972, Name: Code.exe, CPU: 14.3%
#
# Network - Sent: 4.21 MB, Received: 27.08 MB
#
# ===== SYSTEM MONITOR =====
# CPU Usage: 7.0%
# Memory Used: 12.00 GB / 15.70 GB (76.5%)
#
# Top CPU-consuming processes:
# PID: 0, Name: System Idle Process, CPU: 1498.5%
# PID: 15496, Name: Code.exe, CPU: 16.6%
# PID: 14972, Name: Code.exe, CPU: 14.0%
#
# Network - Sent: 4.21 MB, Received: 27.10 MB
#
# Task Manager Stopped.
